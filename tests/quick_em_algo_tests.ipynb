# %%
import sys

sys.path.insert(1, "../")

# %%
# %cd ../
# %run tests/quick_test.py
# %cd tests/
# Out:
# c:\toxakaz\projects\2024\EM-algo\.venv\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# c:\toxakaz\projects\2024\EM-algo
#   0%|          | 0/60 [00:00<?, ?it/s]
# c:\toxakaz\projects\2024\EM-algo\tests

# %%
from em_algo.utils import *

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
from test_utils import *

results = open_results("quick_test")

# %%
for result in results:

    table = [
        [
            d.model.name(),
            tuple(d.model.params_convert_from_model(d.params)),
            d.prior_probability
        ]
        for d in result.result.distributions
    ]
    df = pd.DataFrame(table, columns=["name", "params", "prior_probability"])
    print(df)
    print(f"samples count: {len(result.test.data)}")
    print(f"time         : {result.time:.3f}")
    print(f"steps        : {result.result.steps} / {result.test.max_step}")
    print(f"error        : {result.result.error}")
    fig, ax1 = plt.subplots()
    ax1.set_xlabel("x")

    sns.histplot(result.test.data, color="lightgrey", label="samples")
    ax2 = ax1.twinx()
    ax2.set_ylabel("p(x)")

    min_data = min(result.test.base_data)
    max_data = max(result.test.base_data)

    def p(x):
        s = 0
        for d in result.result.distributions:
            if d.prior_probability is not None:
                s += d.prior_probability * d.model.p(x, d.params)
        return s
    
    def p_t(x):
        s = 0
        w = 1 / result.test.k
        for d in result.test.base_distributions:
            s += w * d.model.p(x, d.params)
        return s

    X = list(np.linspace(min_data, max_data, int(np.abs(max_data - min_data) * 512)))
    Y = [p(x) for x in X]
    ax2.plot(X, [p_t(x) for x in X], "--", color="green", label="target")
    ax2.plot(X, [p(x) for x in X], color="red", label="result")
    ax2.legend()
    plt.show()
    print()
    print()
# Out:
#          name                                    params  prior_probability
# 0  WeibullExp  (14.583885913901286, 0.8652944080971162)                1.0
# samples count: 50
# time         : 0.023
# steps        : 2 / 16
# error        : None
#          name                                   params  prior_probability
# 0  WeibullExp  (14.982306334305918, 0.860731760631733)                1.0
# samples count: 100
# time         : 0.045
# steps        : 2 / 16
# error        : None
#          name                                   params  prior_probability
# 0  WeibullExp  (17.07048739292982, 0.8682069823502298)                1.0
# samples count: 200
# time         : 0.084
# steps        : 2 / 16
# error        : None
#          name                                   params  prior_probability
# 0  WeibullExp  (15.56005299072189, 0.8646070398086182)                1.0
# samples count: 500
# time         : 0.190
# steps        : 2 / 16
# error        : None
#          name                                    params  prior_probability
# 0  WeibullExp  (3.7459403284804385, 1.7523110334580965)           0.439998
# 1  WeibullExp   (8.109588007311375, 11.972185107277292)           0.560002
# samples count: 50
# time         : 0.091
# steps        : 4 / 16
# error        : None
#          name                                    params  prior_probability
# 0  WeibullExp   (4.064537863566914, 1.7963656671288943)               0.55
# 1  WeibullExp  (10.661524838459867, 12.301630139818016)               0.45
# samples count: 100
# time         : 0.056
# steps        : 2 / 16
# error        : None
#          name                                   params  prior_probability
# 0  WeibullExp  (4.324347936771127, 1.7755308354967907)            0.48499
# 1  WeibullExp  (7.571770907466523, 11.848016008009624)            0.51501
# samples count: 200
# time         : 0.108
# steps        : 2 / 16
# error        : None
#          name                                   params  prior_probability
# 0  WeibullExp  (3.933486604347201, 1.7992204963375682)           0.517991
# 1  WeibullExp  (7.742198923458812, 12.053085196757639)           0.482009
# samples count: 500
# time         : 0.991
# steps        : 7 / 16
# error        : None
#          name                                   params  prior_probability
# 0  WeibullExp   (1.922927374174793, 2.084631588257162)           0.276983
# 1  WeibullExp  (2.545530339607006, 11.231660696857702)           0.466321
# 2  WeibullExp  (34.05336626777554, 18.183716058475422)           0.256697
# samples count: 50
# time         : 0.377
# steps        : 16 / 16
# error        : None
#          name                                     params  prior_probability
# 0  WeibullExp    (2.6316547175001594, 2.926431053691037)           0.471019
# 1  WeibullExp  (107.12905184325379, 0.02804910577498667)           0.010000
# 2  WeibullExp    (3.787494284842725, 14.897362103612858)           0.518981
# samples count: 100
# time         : 6.029
# steps        : 7 / 16
# error        : None
#          name                                    params  prior_probability
# 0  WeibullExp  (4.1269698324715804, 15.327424335848217)           0.629895
# 1  WeibullExp   (2.3677402084339096, 2.645406518531071)           0.335914
# 2  WeibullExp    (9.897258854534378, 1.864234914555644)           0.034191
# samples count: 200
# time         : 1.339
# steps        : 16 / 16
# error        : None
#          name                                    params  prior_probability
# 0  WeibullExp   (1.4346051606628953, 7.935048136391173)           0.729749
# 1  WeibullExp  (19.294011080699732, 18.265071322465566)           0.188260
# 2  WeibullExp    (25.73938440687099, 18.73197935604283)           0.081991
# samples count: 500
# time         : 3.738
# steps        : 16 / 16
# error        : None
#          name                                    params  prior_probability
# 0  WeibullExp   (22.00782147591545, 21.245717239278825)                NaN
# 1  WeibullExp             (inf, 5.958595534602544e-156)                NaN
# 2  WeibullExp  (10.530204715784144, 17.871943613463237)                NaN
# 3  WeibullExp   (20.902798330572526, 2.178900527797162)                NaN
# samples count: 50
# time         : 0.310
# steps        : 6 / 16
# error        : All models can't match due prior probability
#          name                                   params  prior_probability
# 0  WeibullExp  (8.988295931742549, 19.725704044680395)           0.470001
# 1  WeibullExp  (17.19829911458054, 4.2279051100046345)           0.370298
# 2  WeibullExp   (318.7812217392979, 4.523240639318767)           0.047200
# 3  WeibullExp    (27.57370859838459, 4.43875165467352)           0.112501
# samples count: 100
# time         : 0.743
# steps        : 12 / 16
# error        : None
#          name                                   params  prior_probability
# 0  WeibullExp    (20.545845039737603, 4.0858936851072)           0.329046
# 1  WeibullExp  (36.19968957548909, 12.717917634538642)           0.017549
# 2  WeibullExp  (30.719720229521197, 4.506202194064771)           0.150953
# 3  WeibullExp   (12.244898483009484, 20.2444338016454)           0.502451
# samples count: 200
# time         : 2.095
# steps        : 16 / 16
# error        : None
#          name                                    params  prior_probability
# 0  WeibullExp  (15.318481227710176, 4.2496804707021045)           0.494000
# 1  WeibullExp  (13.266376963000187, 20.911935035228183)           0.214595
# 2  WeibullExp   (24.39230471199199, 11.377373050898145)           0.003604
# 3  WeibullExp   (10.112975976943588, 19.32928416078415)           0.287802
# samples count: 500
# time         : 3.979
# steps        : 11 / 16
# error        : None
#          name                                    params  prior_probability
# 0  WeibullExp    (26.08730596323987, 5.969976768774939)           0.230861
# 1  WeibullExp   (19.724630018506907, 17.45645730348926)                NaN
# 2  WeibullExp  (1.9546690775355622, 14.181867820364907)           0.536341
# 3  WeibullExp   (15.111081907643658, 10.07615086510342)           0.198837
# 4  WeibullExp    (91.08511511094775, 4.294713808575414)           0.033961
# samples count: 50
# time         : 0.646
# steps        : 16 / 16
# error        : None
#          name                                    params  prior_probability
# 0  WeibullExp   (7.119566324231986, 23.034660150311627)           0.013996
# 1  WeibullExp  (12.119480619094587, 26.500033082633074)           0.038627
# 2  WeibullExp    (2.60676791288919, 11.243162393575158)           0.860507
# 3  WeibullExp   (6.813019697995759, 18.575128339892455)           0.077195
# 4  WeibullExp   (175.90916071821582, 1.848686281103898)           0.009675
# samples count: 100
# time         : 15.363
# steps        : 16 / 16
# error        : None
#          name                                    params  prior_probability
# 0  WeibullExp  (9.550367142551352, 0.41381698015444496)                NaN
# 1  WeibullExp    (9.365706876136082, 6.051165419601065)           0.128951
# 2  WeibullExp   (4.296323455092661, 10.938730722500685)           0.587522
# 3  WeibullExp   (9.648526529945846, 21.408951260558393)           0.068800
# 4  WeibullExp   (5.684246021313871, 17.342022879430626)           0.214727
# samples count: 200
# time         : 1.828
# steps        : 14 / 16
# error        : None
#          name                                    params  prior_probability
# 0  WeibullExp  (49.295265533666935, 1.2635854880627748)                NaN
# 1  WeibullExp    (5.931467087159421, 16.01708677249234)           0.141925
# 2  WeibullExp    (4.375678344317327, 18.78641220902362)           0.116062
# 3  WeibullExp   (3.2930741925814675, 9.556154437530717)           0.572246
# 4  WeibullExp  (2.1437816718781444, 15.347478320638995)           0.169766
# samples count: 500
# time         : 8.961
# steps        : 16 / 16
# error        : None
#        name                                    params  prior_probability
# 0  Gaussian  (-17.21852634638116, 28.426240990272472)                1.0
# samples count: 50
# time         : 0.037
# steps        : 2 / 16
# error        : None
#        name                                   params  prior_probability
# 0  Gaussian  (-14.81375836122647, 26.70582121375422)                1.0
# samples count: 100
# time         : 0.043
# steps        : 2 / 16
# error        : None
#        name                                     params  prior_probability
# 0  Gaussian  (-15.726345785108318, 24.315723718802822)                1.0
# samples count: 200
# time         : 0.053
# steps        : 2 / 16
# error        : None
#        name                                    params  prior_probability
# 0  Gaussian  (-15.174843114726679, 22.41370058236127)                1.0
# samples count: 500
# time         : 0.115
# steps        : 2 / 16
# error        : None
#        name                                   params  prior_probability
# 0  Gaussian  (9.401892460520523, 11.022541906820246)           0.504786
# 1  Gaussian  (-18.00831395264665, 15.30893119378207)           0.495214
# samples count: 50
# time         : 0.261
# steps        : 16 / 16
# error        : None
#        name                                    params  prior_probability
# 0  Gaussian  (5.3724740545536385, 12.604438617258046)           0.735212
# 1  Gaussian   (-26.2840135458541, 14.836351709887051)           0.264788
# samples count: 100
# time         : 0.680
# steps        : 16 / 16
# error        : None
#        name                                    params  prior_probability
# 0  Gaussian    (5.625080708937775, 9.306971401576067)            0.56704
# 1  Gaussian  (-20.55575333780426, 17.618160956318775)            0.43296
# samples count: 200
# time         : 0.853
# steps        : 16 / 16
# error        : None
#        name                                    params  prior_probability
# 0  Gaussian  (-13.631985412616196, 18.50558014924082)           0.515308
# 1  Gaussian   (7.9653302935059385, 9.989401397913047)           0.484692
# samples count: 500
# time         : 1.995
# steps        : 16 / 16
# error        : None
#        name                                    params  prior_probability
# 0  Gaussian    (8.549442085021262, 18.97019237752909)           0.317692
# 1  Gaussian    (9.69098550756379, 4.6538357448920875)           0.295157
# 2  Gaussian  (-9.974753946520137, 11.110994914384603)           0.387152
# samples count: 50
# time         : 0.302
# steps        : 16 / 16
# error        : None
#        name                                     params  prior_probability
# 0  Gaussian  (-25.484781837984077, 12.279511834656937)           0.069640
# 1  Gaussian  (-2.0297727919357396, 20.982305331077786)           0.542648
# 2  Gaussian      (7.577718403765156, 4.29125726607026)           0.387712
# samples count: 100
# time         : 0.733
# steps        : 16 / 16
# error        : None
#        name                                    params  prior_probability
# 0  Gaussian  (-8.846807867908995, 19.981721812344496)           0.439549
# 1  Gaussian   (9.525044625973647, 13.860504629839188)           0.525083
# 2  Gaussian  (-2.1198791052890567, 6.817767040848798)           0.035368
# samples count: 200
# time         : 1.428
# steps        : 16 / 16
# error        : None
#        name                                      params  prior_probability
# 0  Gaussian      (6.279921309639126, 5.924523912418384)           0.379320
# 1  Gaussian  (-0.21353110292842542, 23.113828600097968)           0.549892
# 2  Gaussian   (-14.801315899920397, 14.085967065368743)           0.070788
# samples count: 500
# time         : 3.294
# steps        : 16 / 16
# error        : None
#        name                                     params  prior_probability
# 0  Gaussian    (3.974368935048794, 10.766239643342384)           0.224704
# 1  Gaussian    (14.374509492024636, 7.815835666148049)           0.278402
# 2  Gaussian  (-15.238639795780085, 4.8183567797704026)           0.255265
# 3  Gaussian     (-6.190360274345949, 7.39525466114729)           0.241629
# samples count: 50
# time         : 0.535
# steps        : 16 / 16
# error        : None
#        name                                     params  prior_probability
# 0  Gaussian    (-14.09870954029614, 10.15033639133924)           0.438661
# 1  Gaussian    (11.926548640308862, 4.775743191310925)           0.263970
# 2  Gaussian  (-3.2226998353397973, 0.8142255787554302)           0.105571
# 3  Gaussian      (8.17116707620852, 5.703090343227089)           0.191798
# samples count: 100
# time         : 0.941
# steps        : 16 / 16
# error        : None
#        name                                     params  prior_probability
# 0  Gaussian    (4.949540925759813, 10.073426475342789)           0.250452
# 1  Gaussian     (7.844164606161247, 8.722027197632817)           0.229839
# 2  Gaussian   (-13.566853259528639, 9.437993530267654)           0.293419
# 3  Gaussian  (-11.326905199575615, 14.407938579713308)           0.226290
# samples count: 200
# time         : 1.693
# steps        : 16 / 16
# error        : None
#        name                                     params  prior_probability
# 0  Gaussian  (-3.2386635901260523, 0.5094712990361784)           0.028758
# 1  Gaussian    (11.102903059555592, 5.973669586432271)           0.183261
# 2  Gaussian    (-8.87451504580142, 13.228570846208141)           0.723982
# 3  Gaussian    (13.979144575483836, 2.943402555128463)           0.064000
# samples count: 500
# time         : 5.952
# steps        : 16 / 16
# error        : None
#        name                                    params  prior_probability
# 0  Gaussian  (-14.964372003733557, 3.616063785804861)           0.251714
# 1  Gaussian   (-8.417106618493683, 17.30079548735682)           0.195344
# 2  Gaussian    (5.766645227619564, 12.77828924438146)           0.157453
# 3  Gaussian   (-9.36118419117622, 17.341392084183386)           0.198874
# 4  Gaussian  (-8.022615034396797, 17.196924776896058)           0.196615
# samples count: 50
# time         : 0.519
# steps        : 16 / 16
# error        : None
#        name                                     params  prior_probability
# 0  Gaussian    (-13.53889915037771, 6.510423245570893)           0.339761
# 1  Gaussian    (12.720886195488468, 16.24269517714046)           0.122997
# 2  Gaussian  (-10.285693992242257, 16.329924599380043)           0.214738
# 3  Gaussian    (2.638244894030137, 3.4772169461126747)           0.147531
# 4  Gaussian      (5.453747283463424, 18.6142006994891)           0.174972
# samples count: 100
# time         : 1.062
# steps        : 16 / 16
# error        : None
#        name                                     params  prior_probability
# 0  Gaussian    (7.0954222324242515, 6.166109079239375)           0.093636
# 1  Gaussian   (-13.530806655241589, 6.824441922900146)           0.354349
# 2  Gaussian  (-1.0817238347472324, 21.302832391094594)           0.208564
# 3  Gaussian   (-10.332474371193573, 17.36377874372626)           0.223785
# 4  Gaussian    (11.934253461605003, 10.15342727152987)           0.119666
# samples count: 200
# time         : 1.749
# steps        : 16 / 16
# error        : None
#        name                                     params  prior_probability
# 0  Gaussian  (-13.414060474722517, 13.278860956586037)           0.259399
# 1  Gaussian   (1.3639706627696158, 17.046215542865603)           0.236338
# 2  Gaussian   (1.1351870047051889, 17.020895225322406)           0.224110
# 3  Gaussian     (6.573635982815556, 7.859338616764174)           0.040721
# 4  Gaussian   (-11.068806535735042, 7.708342861166842)           0.239431
# samples count: 500
# time         : 5.094
# steps        : 16 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (13.627084748765329,)                1.0
# samples count: 50
# time         : 0.004
# steps        : 2 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (11.923835879388179,)                1.0
# samples count: 100
# time         : 0.007
# steps        : 2 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (11.737314745693075,)                1.0
# samples count: 200
# time         : 0.012
# steps        : 2 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (12.751729619781477,)                1.0
# samples count: 500
# time         : 0.033
# steps        : 2 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (0.9604438085342341,)           0.434849
# 1  Exponential  (13.193122060103992,)           0.565151
# samples count: 50
# time         : 0.049
# steps        : 9 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential   (14.94799010875679,)           0.524501
# 1  Exponential  (1.2611897707791075,)           0.475499
# samples count: 100
# time         : 0.114
# steps        : 13 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (1.2714978723082542,)           0.559318
# 1  Exponential  (13.916967576441523,)           0.440682
# samples count: 200
# time         : 0.309
# steps        : 16 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential   (16.34786165948412,)            0.50334
# 1  Exponential  (1.0642080709198245,)            0.49666
# samples count: 500
# time         : 0.279
# steps        : 6 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential    (22.3296768783196,)           0.332061
# 1  Exponential  (1.1862996846986515,)           0.403686
# 2  Exponential  (16.830081592789078,)           0.264254
# samples count: 50
# time         : 0.048
# steps        : 9 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (0.8649440893590176,)           0.229969
# 1  Exponential  (27.347837628327405,)           0.526935
# 2  Exponential  (3.2712573448146105,)           0.243096
# samples count: 100
# time         : 0.061
# steps        : 4 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (20.857084766177334,)           0.272867
# 1  Exponential  (23.605274001659552,)           0.367634
# 2  Exponential  (1.1999106465363498,)           0.359499
# samples count: 200
# time         : 0.360
# steps        : 15 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (17.485954126141092,)           0.195866
# 1  Exponential   (1.118854704990183,)           0.349098
# 2  Exponential  (25.453729088267135,)           0.455036
# samples count: 500
# time         : 0.817
# steps        : 16 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential   (19.09231736320902,)           0.258842
# 1  Exponential  (17.956394831114558,)           0.254511
# 2  Exponential   (7.813219388578848,)           0.221917
# 3  Exponential  (21.880437362463105,)           0.264730
# samples count: 50
# time         : 0.065
# steps        : 8 / 16
# error        : None
#           name                params  prior_probability
# 0  Exponential  (22.05922625861665,)           0.309620
# 1  Exponential  (18.92505917360697,)           0.266757
# 2  Exponential  (16.97547947718211,)           0.239165
# 3  Exponential  (7.285967301891217,)           0.184457
# samples count: 100
# time         : 0.229
# steps        : 11 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (11.713203989472474,)           0.166637
# 1  Exponential  (12.612231827447278,)           0.266647
# 2  Exponential  (15.291145941672227,)           0.284017
# 3  Exponential  (20.218680949127176,)           0.282700
# samples count: 200
# time         : 0.295
# steps        : 12 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (13.957844211551512,)           0.099950
# 1  Exponential  (16.352421588783937,)           0.327843
# 2  Exponential  (15.798029425509359,)           0.329174
# 3  Exponential  (14.351630687778584,)           0.243033
# samples count: 500
# time         : 1.039
# steps        : 14 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential   (4.206978987516654,)           0.161572
# 1  Exponential  (17.817809658529338,)           0.187884
# 2  Exponential   (6.144499895662921,)           0.260046
# 3  Exponential   (11.63730716448647,)           0.187038
# 4  Exponential  (0.5423485301759514,)           0.203461
# samples count: 50
# time         : 0.187
# steps        : 16 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential   (7.867820084351287,)           0.178208
# 1  Exponential   (8.705917972398048,)           0.169189
# 2  Exponential    (4.69214666293359,)           0.222671
# 3  Exponential   (29.66992595331469,)           0.140616
# 4  Exponential  (0.5369646617365854,)           0.289316
# samples count: 100
# time         : 0.404
# steps        : 16 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (5.8494010410812844,)           0.225079
# 1  Exponential   (5.260913185980363,)           0.247941
# 2  Exponential  (0.4656585800220215,)           0.182825
# 3  Exponential  (26.406491228433143,)           0.166295
# 4  Exponential   (9.124466672796476,)           0.177860
# samples count: 200
# time         : 0.530
# steps        : 16 / 16
# error        : None
#           name                 params  prior_probability
# 0  Exponential  (0.4004197304755873,)           0.178788
# 1  Exponential    (5.97720944653495,)           0.231465
# 2  Exponential  (14.759364214505707,)           0.172822
# 3  Exponential    (3.72417762640564,)           0.218138
# 4  Exponential  (10.336766263710158,)           0.198788
# samples count: 500
# time         : 0.856
# steps        : 8 / 16
# error        : None
