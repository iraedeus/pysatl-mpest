# %%
import sys

sys.path.insert(1, "../")

# %%
from em_algo.models import WeibullModelExp, GaussianModel, ExponentialModel
from em_algo.types import *
from em_algo.distribution_mixture import DistributionMixture, DistributionInMixture
from examples.utils import SingleSolverResult

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

import itertools

from tqdm import tqdm
from tqdm.contrib.concurrent import process_map

# %%
from examples.utils import *

results = open_results("big_mono_test")

# %%
from examples.prepare_result import prepare

df = prepare(results)
df["occur"] = df["occur"].replace([np.inf, -np.inf], np.nan)
# Out:
#   0%|          | 0/92160 [00:00<?, ?it/s]

# %%
df["error"].unique()
# Out:
# array([None], dtype=object)

# %%
df = df.drop(columns=["error"])

# %%
df["success"] = (df["steps"] < 16) & any(df["result_mixture"].values)

# %%
df["success"].value_counts()
# Out:
# success
# True     61211
# False    30949
# Name: count, dtype: int64

# %%
df["failed"].value_counts()
# Out:
# failed
# False    90914
# True      1246
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    test_index      optimizer  k  \
# 0           0        ScipyCG  1
# 1           0  ScipyNewtonCG  1
# 2           0     ScipySLSQP  1
# 3           0       ScipyTNC  1
# 4           1        ScipyCG  1
#
#                                               sample  \
# 0  [0.9173885735853511, 0.9069174216468057, 0.851...
# 1  [0.9173885735853511, 0.9069174216468057, 0.851...
# 2  [0.9173885735853511, 0.9069174216468057, 0.851...
# 3  [0.9173885735853511, 0.9069174216468057, 0.851...
# 4  [0.9173885735853511, 0.9069174216468057, 0.851...
#
#                                         true_mixture  \
# 0  (<em_algo.distribution_mixture.DistributionInM...
# 1  (<em_algo.distribution_mixture.DistributionInM...
# 2  (<em_algo.distribution_mixture.DistributionInM...
# 3  (<em_algo.distribution_mixture.DistributionInM...
# 4  (<em_algo.distribution_mixture.DistributionInM...
#
#                                       result_mixture log  steps      time  \
# 0  (<em_algo.distribution_mixture.DistributionInM...  []      2  0.045785
# 1  (<em_algo.distribution_mixture.DistributionInM...  []      2  0.039017
# 2  (<em_algo.distribution_mixture.DistributionInM...  []      2  0.037471
# 3  (<em_algo.distribution_mixture.DistributionInM...  []      2  0.043206
# 4  (<em_algo.distribution_mixture.DistributionInM...  []      2  0.255229
#
#         model  size  success  failed     occur
# 0  WeibullExp    50     True   False  1.345529
# 1  WeibullExp    50     True   False  1.345529
# 2  WeibullExp    50     True   False  1.345531
# 3  WeibullExp    50     True   False  1.345528
# 4  WeibullExp    50     True   False  1.345529

# %%
df.select_dtypes(["number", "bool"])
# Out:
#        test_index  k  steps      time  size  success  failed     occur
# 0               0  1      2  0.045785    50     True   False  1.345529
# 1               0  1      2  0.039017    50     True   False  1.345529
# 2               0  1      2  0.037471    50     True   False  1.345531
# 3               0  1      2  0.043206    50     True   False  1.345528
# 4               1  1      2  0.255229    50     True   False  1.345529
# ...           ... ..    ...       ...   ...      ...     ...       ...
# 92155       23038  3      7  1.421419  1000     True   False  0.444505
# 92156       23039  3     13  4.619542  1000     True   False  0.443455
# 92157       23039  3     13  5.624392  1000     True   False  0.443455
# 92158       23039  3     13  4.755351  1000     True   False  0.443456
# 92159       23039  3     13  5.462942  1000     True   False  0.443455
#
# [92160 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
categorical_cols = (
    df.drop(columns=["true_mixture", "result_mixture", "sample", "log"])
    .select_dtypes(include=["object"])
    .columns
)

corr_df = pd.DataFrame(df)

for col in categorical_cols:
    corr_df[col] = le.fit_transform(df[col])

corr_df = corr_df.select_dtypes(["number", "bool"])
corr_df = corr_df.drop(columns=["test_index"])

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
corr_df = pd.DataFrame(scaler.fit_transform(corr_df), columns=corr_df.columns)

df_corr = corr_df.corr()
plt.figure(figsize=(12, 6))
sns.heatmap(df_corr, annot=True, cmap="Dark2")
plt.title("Correlation Matrix")
plt.show()

# %%
df[df["optimizer"] == "ScipyNewtonCG"]
# Out:
#        test_index      optimizer  k  \
# 1               0  ScipyNewtonCG  1
# 5               1  ScipyNewtonCG  1
# 9               2  ScipyNewtonCG  1
# 13              3  ScipyNewtonCG  1
# 17              4  ScipyNewtonCG  1
# ...           ...            ... ..
# 92141       23035  ScipyNewtonCG  3
# 92145       23036  ScipyNewtonCG  3
# 92149       23037  ScipyNewtonCG  3
# 92153       23038  ScipyNewtonCG  3
# 92157       23039  ScipyNewtonCG  3
#
#                                                   sample  \
# 1      [0.9173885735853511, 0.9069174216468057, 0.851...
# 5      [0.9173885735853511, 0.9069174216468057, 0.851...
# 9      [0.9173885735853511, 0.9069174216468057, 0.851...
# 13     [0.9173885735853511, 0.9069174216468057, 0.851...
# 17     [0.9173885735853511, 0.9069174216468057, 0.851...
# ...                                                  ...
# 92141  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92145  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92149  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92153  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92157  [0.2457181585429831, 0.1478108554740685, 0.279...
#
#                                             true_mixture  \
# 1      (<em_algo.distribution_mixture.DistributionInM...
# 5      (<em_algo.distribution_mixture.DistributionInM...
# 9      (<em_algo.distribution_mixture.DistributionInM...
# 13     (<em_algo.distribution_mixture.DistributionInM...
# 17     (<em_algo.distribution_mixture.DistributionInM...
# ...                                                  ...
# 92141  (<em_algo.distribution_mixture.DistributionInM...
# 92145  (<em_algo.distribution_mixture.DistributionInM...
# 92149  (<em_algo.distribution_mixture.DistributionInM...
# 92153  (<em_algo.distribution_mixture.DistributionInM...
# 92157  (<em_algo.distribution_mixture.DistributionInM...
#
#                                           result_mixture log  steps      time  \
# 1      (<em_algo.distribution_mixture.DistributionInM...  []      2  0.039017
# 5      (<em_algo.distribution_mixture.DistributionInM...  []      2  0.165643
# 9      (<em_algo.distribution_mixture.DistributionInM...  []      2  0.087084
# 13     (<em_algo.distribution_mixture.DistributionInM...  []      2  0.127498
# 17     (<em_algo.distribution_mixture.DistributionInM...  []      2  0.081151
# ...                                                  ...  ..    ...       ...
# 92141  (<em_algo.distribution_mixture.DistributionInM...  []      2  1.018595
# 92145  (<em_algo.distribution_mixture.DistributionInM...  []     16  6.210426
# 92149  (<em_algo.distribution_mixture.DistributionInM...  []     11  4.514465
# 92153  (<em_algo.distribution_mixture.DistributionInM...  []      7  1.331243
# 92157  (<em_algo.distribution_mixture.DistributionInM...  []     13  5.624392
#
#              model  size  success  failed     occur
# 1       WeibullExp    50     True   False  1.345529
# 5       WeibullExp    50     True   False  1.345529
# 9       WeibullExp    50     True   False  1.345529
# 13      WeibullExp    50     True   False  1.345529
# 17      WeibullExp    50     True   False  1.345529
# ...            ...   ...      ...     ...       ...
# 92141  Exponential  1000     True   False  0.442576
# 92145  Exponential  1000    False   False  0.444245
# 92149  Exponential  1000     True   False  0.443906
# 92153  Exponential  1000     True   False  0.444505
# 92157  Exponential  1000     True   False  0.443455
#
# [23040 rows x 14 columns]

# %%
for opt in df["optimizer"].unique():
    print(opt)
    print(df[df["optimizer"] == opt]["failed"].value_counts())
    print("time")
    print(df[df["optimizer"] == opt]["time"].mean())
    print("steps")
    print(df[df["optimizer"] == opt]["steps"].mean())
    print("occur")
    print(df[df["optimizer"] == opt]["occur"].mean())
    print()
# Out:
# ScipyCG
# failed
# False    22373
# True       667
# Name: count, dtype: int64
# time
# 5.717425486933222
# steps
# 8.442838541666667
# occur
# -1.569184633972185
#
# ScipyNewtonCG
# failed
# False    22748
# True       292
# Name: count, dtype: int64
# time
# 4.500826544573996
# steps
# 8.701779513888889
# occur
# -1.5887504950529545
#
# ScipySLSQP
# failed
# False    22797
# True       243
# Name: count, dtype: int64
# time
# 3.627200289584775
# steps
# 8.643446180555555
# occur
# -1.5872305692900557
#
# ScipyTNC
# failed
# False    22996
# True        44
# Name: count, dtype: int64
# time
# 4.886238893902783
# steps
# 8.686805555555555
# occur
# -1.627795400315431

# %%
print(df["occur"].min())
print(df["occur"].max())
# Out:
# -14.13727946131802
# 1.925573931953645

# %%
mdf = df[df["k"] > 1]
mdf
# Out:
#        test_index      optimizer  k  \
# 10240        2560        ScipyCG  2
# 10241        2560  ScipyNewtonCG  2
# 10242        2560     ScipySLSQP  2
# 10243        2560       ScipyTNC  2
# 10244        2561        ScipyCG  2
# ...           ...            ... ..
# 92155       23038       ScipyTNC  3
# 92156       23039        ScipyCG  3
# 92157       23039  ScipyNewtonCG  3
# 92158       23039     ScipySLSQP  3
# 92159       23039       ScipyTNC  3
#
#                                                   sample  \
# 10240  [4.857703838168679, 4.651561884684546, 4.87227...
# 10241  [4.857703838168679, 4.651561884684546, 4.87227...
# 10242  [4.857703838168679, 4.651561884684546, 4.87227...
# 10243  [4.857703838168679, 4.651561884684546, 4.87227...
# 10244  [4.857703838168679, 4.651561884684546, 4.87227...
# ...                                                  ...
# 92155  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92156  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92157  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92158  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92159  [0.2457181585429831, 0.1478108554740685, 0.279...
#
#                                             true_mixture  \
# 10240  (<em_algo.distribution_mixture.DistributionInM...
# 10241  (<em_algo.distribution_mixture.DistributionInM...
# 10242  (<em_algo.distribution_mixture.DistributionInM...
# 10243  (<em_algo.distribution_mixture.DistributionInM...
# 10244  (<em_algo.distribution_mixture.DistributionInM...
# ...                                                  ...
# 92155  (<em_algo.distribution_mixture.DistributionInM...
# 92156  (<em_algo.distribution_mixture.DistributionInM...
# 92157  (<em_algo.distribution_mixture.DistributionInM...
# 92158  (<em_algo.distribution_mixture.DistributionInM...
# 92159  (<em_algo.distribution_mixture.DistributionInM...
#
#                                           result_mixture log  steps      time  \
# 10240  (<em_algo.distribution_mixture.DistributionInM...  []     16  0.485679
# 10241  (<em_algo.distribution_mixture.DistributionInM...  []     16  0.387358
# 10242  (<em_algo.distribution_mixture.DistributionInM...  []      2  0.276656
# 10243  (<em_algo.distribution_mixture.DistributionInM...  []     16  0.321019
# 10244  (<em_algo.distribution_mixture.DistributionInM...  []     16  1.367080
# ...                                                  ...  ..    ...       ...
# 92155  (<em_algo.distribution_mixture.DistributionInM...  []      7  1.421419
# 92156  (<em_algo.distribution_mixture.DistributionInM...  []     13  4.619542
# 92157  (<em_algo.distribution_mixture.DistributionInM...  []     13  5.624392
# 92158  (<em_algo.distribution_mixture.DistributionInM...  []     13  4.755351
# 92159  (<em_algo.distribution_mixture.DistributionInM...  []     13  5.462942
#
#              model  size  success  failed     occur
# 10240   WeibullExp    50    False   False -1.510390
# 10241   WeibullExp    50    False   False -1.510390
# 10242   WeibullExp    50     True   False -1.510382
# 10243   WeibullExp    50    False   False -1.510390
# 10244   WeibullExp    50    False   False -1.325253
# ...            ...   ...      ...     ...       ...
# 92155  Exponential  1000     True   False  0.444505
# 92156  Exponential  1000     True   False  0.443455
# 92157  Exponential  1000     True   False  0.443455
# 92158  Exponential  1000     True   False  0.443456
# 92159  Exponential  1000     True   False  0.443455
#
# [61440 rows x 14 columns]

# %%
calc_success_rate_hash = dict()

def calc_success_rate(row, column):
    k = row["k"]
    size = row["size"]
    model = row["model"]
    optimizer = row["optimizer"]

    if (k, size, model, optimizer) in calc_success_rate_hash:
        return calc_success_rate_hash[(k, size, model, optimizer)]

    dfoi = mdf[
        (mdf["k"] == k)
        & (mdf["size"] == size)
        & (mdf["model"] == model)
        & (mdf["optimizer"] == optimizer)

    ]

    calc_success_rate_hash[(k, size, model, optimizer)] = (
        dfoi[column].sum() / len(dfoi) * 100
    )

    return calc_success_rate_hash[(k, size, model, optimizer)]


mdf["success_rate"] = mdf.apply(partial(calc_success_rate, column="success"), axis=1)
calc_success_rate_hash = dict()
mdf["fail_rate"] = mdf.apply(partial(calc_success_rate, column="failed"), axis=1)
# Out:
# C:\Users\toxakaz\AppData\Local\Temp\ipykernel_101504\3402195708.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mdf["success_rate"] = mdf.apply(partial(calc_success_rate, column="success"), axis=1)
# C:\Users\toxakaz\AppData\Local\Temp\ipykernel_101504\3402195708.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mdf["fail_rate"] = mdf.apply(partial(calc_success_rate, column="failed"), axis=1)

# %%
mdf
# Out:
#        test_index      optimizer  k  \
# 10240        2560        ScipyCG  2
# 10241        2560  ScipyNewtonCG  2
# 10242        2560     ScipySLSQP  2
# 10243        2560       ScipyTNC  2
# 10244        2561        ScipyCG  2
# ...           ...            ... ..
# 92155       23038       ScipyTNC  3
# 92156       23039        ScipyCG  3
# 92157       23039  ScipyNewtonCG  3
# 92158       23039     ScipySLSQP  3
# 92159       23039       ScipyTNC  3
#
#                                                   sample  \
# 10240  [4.857703838168679, 4.651561884684546, 4.87227...
# 10241  [4.857703838168679, 4.651561884684546, 4.87227...
# 10242  [4.857703838168679, 4.651561884684546, 4.87227...
# 10243  [4.857703838168679, 4.651561884684546, 4.87227...
# 10244  [4.857703838168679, 4.651561884684546, 4.87227...
# ...                                                  ...
# 92155  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92156  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92157  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92158  [0.2457181585429831, 0.1478108554740685, 0.279...
# 92159  [0.2457181585429831, 0.1478108554740685, 0.279...
#
#                                             true_mixture  \
# 10240  (<em_algo.distribution_mixture.DistributionInM...
# 10241  (<em_algo.distribution_mixture.DistributionInM...
# 10242  (<em_algo.distribution_mixture.DistributionInM...
# 10243  (<em_algo.distribution_mixture.DistributionInM...
# 10244  (<em_algo.distribution_mixture.DistributionInM...
# ...                                                  ...
# 92155  (<em_algo.distribution_mixture.DistributionInM...
# 92156  (<em_algo.distribution_mixture.DistributionInM...
# 92157  (<em_algo.distribution_mixture.DistributionInM...
# 92158  (<em_algo.distribution_mixture.DistributionInM...
# 92159  (<em_algo.distribution_mixture.DistributionInM...
#
#                                           result_mixture log  steps      time  \
# 10240  (<em_algo.distribution_mixture.DistributionInM...  []     16  0.485679
# 10241  (<em_algo.distribution_mixture.DistributionInM...  []     16  0.387358
# 10242  (<em_algo.distribution_mixture.DistributionInM...  []      2  0.276656
# 10243  (<em_algo.distribution_mixture.DistributionInM...  []     16  0.321019
# 10244  (<em_algo.distribution_mixture.DistributionInM...  []     16  1.367080
# ...                                                  ...  ..    ...       ...
# 92155  (<em_algo.distribution_mixture.DistributionInM...  []      7  1.421419
# 92156  (<em_algo.distribution_mixture.DistributionInM...  []     13  4.619542
# 92157  (<em_algo.distribution_mixture.DistributionInM...  []     13  5.624392
# 92158  (<em_algo.distribution_mixture.DistributionInM...  []     13  4.755351
# 92159  (<em_algo.distribution_mixture.DistributionInM...  []     13  5.462942
#
#              model  size  success  failed     occur  success_rate  fail_rate
# 10240   WeibullExp    50    False   False -1.510390     70.117188  10.351562
# 10241   WeibullExp    50    False   False -1.510390     63.867188   2.929688
# 10242   WeibullExp    50     True   False -1.510382     68.359375   4.687500
# 10243   WeibullExp    50    False   False -1.510390     68.945312   0.390625
# 10244   WeibullExp    50    False   False -1.325253     70.117188  10.351562
# ...            ...   ...      ...     ...       ...           ...        ...
# 92155  Exponential  1000     True   False  0.444505     83.789062   0.000000
# 92156  Exponential  1000     True   False  0.443455     83.789062   0.000000
# 92157  Exponential  1000     True   False  0.443455     83.789062   0.000000
# 92158  Exponential  1000     True   False  0.443456     83.789062   0.000000
# 92159  Exponential  1000     True   False  0.443455     83.789062   0.000000
#
# [61440 rows x 16 columns]

# %%
for model in mdf["model"].unique():
    cdf = mdf[mdf["model"] == model]
    fig, axs = plt.subplots(1, 2, figsize=(16, 8))
    fig.suptitle(model)
    axs[0].set_title("k = 2")
    axs[1].set_title("k = 3")
    sns.boxplot(
        ax=axs[0],
        data=cdf[cdf["k"] == 2],
        x="size",
        y="time",
        hue="optimizer",
        showfliers=False,
    )
    sns.boxplot(
        ax=axs[1],
        data=cdf[cdf["k"] == 3],
        x="size",
        y="time",
        hue="optimizer",
        showfliers=False,
    )
    plt.show()

    fig, axs = plt.subplots(1, 2, figsize=(16, 8))
    fig.suptitle(model)
    axs[0].set_title("k = 2")
    axs[1].set_title("k = 3")
    sns.boxplot(
        ax=axs[0],
        data=cdf[cdf["k"] == 2],
        x="size",
        y="occur",
        hue="optimizer",
        showfliers=False,
    )
    sns.boxplot(
        ax=axs[1],
        data=cdf[cdf["k"] == 3],
        x="size",
        y="occur",
        hue="optimizer",
        showfliers=False,
    )
    plt.show()

    fig, axs = plt.subplots(1, 2, figsize=(16, 9))
    fig.suptitle(model)
    axs[0].set_title("k = 2")
    axs[1].set_title("k = 3")
    sns.barplot(
        ax=axs[0],
        data=cdf[cdf["k"] == 2],
        x="size",
        y="success_rate",
        hue="optimizer",
    )
    sns.barplot(
        ax=axs[1],
        data=cdf[cdf["k"] == 3],
        x="size",
        y="success_rate",
        hue="optimizer",
    )
    plt.show()

    fig, axs = plt.subplots(1, 2, figsize=(16, 9))
    fig.suptitle(model)
    axs[0].set_title("k = 2")
    axs[1].set_title("k = 3")
    sns.barplot(
        ax=axs[0],
        data=cdf[cdf["k"] == 2],
        x="size",
        y="fail_rate",
        hue="optimizer",
    )
    sns.barplot(
        ax=axs[1],
        data=cdf[cdf["k"] == 3],
        x="size",
        y="fail_rate",
        hue="optimizer",
    )
    plt.show()
